# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter
import seaborn as sns
from matplotlib import pyplot as plt

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %%
# Load the data
file_path = Path('Diabetes dataset_Group12.csv')
df = pd.read_csv(file_path)
df = df.drop(columns = "ID")
new_df = df.drop(columns = "Label")
new_df.head()
# Out:
#         FPG   HOMA_IR  Total_TAG  2hr_OGTT      T_CE      T_TAG     T_DAG  \
# 0  6.426266  2.336573   5.781363  6.491854  12.09865  10.273816  4.086167
# 1  6.741468  3.109857   7.906891  7.451211  12.09865  10.807138  4.907486
# 2  6.672426  3.621295   7.000001  6.942515  12.09865  10.273816  4.379796
# 3  6.491854  1.563326   7.011228  6.629358  12.09865  10.273816  4.281923
# 4  6.539160  1.997820   6.285404  6.954197  12.09865   9.228706  3.965879
#
#       T_FFA      T_PC      T_PE  ...  total DMA  alpha-AAA  Creatinine  \
# 0  9.443437  10.80714  7.199930  ...   0.111588   1.874979    6.710942
# 1  8.901539  10.27382  7.402848  ...  -0.692381  -0.488355    6.008138
# 2  8.802699  10.80714  6.759415  ...  -0.032965   0.487615    6.008138
# 3  8.522484  10.80714  6.948541  ...   0.226960   0.382100    6.440727
# 4  8.901539  10.80714  7.082903  ...   1.018463   0.024295    6.532927
#
#    Kynurenine    Met-SO  t4-OH-Pro  Putrescine  Serotonin  Spermidine  \
# 0    2.394366 -5.852678   4.214117   -3.462398  -1.018531   -1.642998
# 1    0.756260 -3.400239   2.677591   -3.313604   0.813043   -2.012510
# 2    1.285267 -4.594876   3.496043   -7.375598  -1.504665   -2.644530
# 3    2.198089 -2.392424   4.504812   -3.638916  -2.520678   -2.473015
# 4    2.766317 -8.606643   3.550989   -2.483951  -1.491908   -1.194648
#
#     Taurine
# 0  6.532927
# 1  7.612722
# 2  6.185453
# 3  5.894638
# 4  6.267509
#
# [5 rows x 105 columns]

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
df['Label'] = df['Label'].astype(str)
df['Label'] = encoder.fit_transform(df['Label'])

# %%
# Create our features
X = new_df

# Create our target
y = df["Label"]

# %%
X.describe()
# Out:
#              FPG    HOMA_IR  Total_TAG   2hr_OGTT       T_CE      T_TAG  \
# count  58.000000  58.000000  58.000000  58.000000  58.000000  58.000000
# mean    6.614549   2.701736   6.844076   6.926155  12.133278  10.319602
# std     0.139946   0.923355   0.822207   0.336438   0.128341   0.613956
# min     6.339851   0.706960   5.584967   5.882646  12.098650   9.004653
# 25%     6.515637   2.153218   6.228442   6.703892  12.098650  10.273816
# 50%     6.607312   2.538648   6.761414   6.906891  12.098650  10.273816
# 75%     6.700441   3.319494   7.266787   7.199572  12.098650  10.673808
# max     6.965785   5.093344   8.774787   7.507795  12.600750  11.408379
#
#            T_DAG      T_FFA       T_PC       T_PE  ...  total DMA  alpha-AAA  \
# count  58.000000  58.000000  58.000000  58.000000  ...  58.000000  58.000000
# mean    4.323889   8.893333  10.669212   7.054732  ...  -0.254614   0.079763
# std     0.329148   0.324070   0.235568   0.295159  ...   0.840540   0.865511
# min     3.531287   8.110500  10.273820   6.440727  ...  -2.520678  -2.973741
# 25%     4.090292   8.710862  10.407150   6.849232  ...  -0.779078  -0.344862
# 50%     4.331543   8.901539  10.807140   7.043002  ...  -0.145946   0.150635
# 75%     4.568362   9.111264  10.807140   7.243204  ...   0.328442   0.473564
# max     4.907486   9.443437  10.807140   7.769827  ...   1.193675   2.141128
#
#        Creatinine  Kynurenine     Met-SO  t4-OH-Pro  Putrescine  Serotonin  \
# count   58.000000   58.000000  58.000000  58.000000   58.000000  58.000000
# mean     6.135712    1.663323  -3.658187   3.805103   -3.972084  -2.809970
# std      0.491906    0.682331   2.969190   0.772432    1.907039   2.188667
# min      4.784064   -0.014012 -10.044284   1.285267  -10.044283 -10.044283
# 25%      5.824147    1.085826  -5.841102   3.483871   -4.613421  -3.881660
# 50%      6.244521    1.781592  -2.782335   3.868034   -3.405381  -2.407604
# 75%      6.532927    2.162975  -1.191318   4.229380   -2.652177  -1.466755
# max      6.798392    3.029029   1.045463   5.202502   -1.147408   0.972990
#
#        Spermidine    Taurine
# count   58.000000  58.000000
# mean    -2.167594   5.531168
# std      0.738385   0.906282
# min     -4.181955   3.590169
# 25%     -2.587629   4.789947
# 50%     -2.127347   5.723925
# 75%     -1.567777   6.185453
# max     -0.933018   7.612722
#
# [8 rows x 105 columns]

# %%
# Check the balance of our target values
y.value_counts()
# Out:
# 1    30
# 0    28
# Name: Label, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)

# %%
# Resample the training data with the BalancedRandomForestClassifier
from imblearn.ensemble import BalancedRandomForestClassifier
randomforest = BalancedRandomForestClassifier(n_estimators = 100, max_depth= 7, max_features='auto', random_state=1)
resampled = randomforest.fit(X_train, y_train)

# %%
# Calculated the balanced accuracy score
from sklearn.metrics import balanced_accuracy_score
yprediction = resampled.predict(X_test)
balanced_accuracy_score(y_test, yprediction)
# Out:
# 0.4017857142857143

# %%
# Display the confusion matrix
from sklearn.metrics import confusion_matrix
matrix = confusion_matrix(y_test, yprediction)
print(matrix)
# Out:
# [[3 4]
#  [5 3]]

# %%
# Print the imbalanced classification report
from imblearn.metrics import classification_report_imbalanced
report = classification_report_imbalanced(y_test, yprediction)
print(report)
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.38      0.43      0.38      0.40      0.40      0.16         7
#           1       0.43      0.38      0.43      0.40      0.40      0.16         8
#
# avg / total       0.40      0.40      0.40      0.40      0.40      0.16        15

# %%
# List the features sorted in descending order by feature importance
feature_names = X.columns
sorted(zip(randomforest.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.04087539014530985, '2hr_OGTT'),
#  (0.03619919442732483, 'SM (OH) C22:2'),
#  (0.03568031716438037, 'SM C24:1'),
#  (0.03088458744793331, 'LCER(24:1)'),
#  (0.02816000635764441, 'SM C20:2'),
#  (0.02476242549388986, 'Kynurenine'),
#  (0.023646532334955256, 'HCER(20:0)'),
#  (0.022954318776152127, 'HCER(24:1)'),
#  (0.021313227799910565, 'SM C16:1'),
#  (0.020952565427809402, 'HCER(18:0)'),
#  (0.02050355012186825, 'CER(24:0)'),
#  (0.019456178841516448, 'LCER(24:0)'),
#  (0.019109342636523963, 'SM C16:0'),
#  (0.01895759911699693, 'HCER(16:0)'),
#  (0.018306272979069955, 'SM C18:0'),
#  (0.018137973509215075, 'Cit'),
#  (0.017293719776083488, 'Gln'),
#  (0.01670962312827344, 'SM (OH) C16:1'),
#  (0.016443525660884025, 'Spermidine'),
#  (0.016268857679687825, 'CER(22:0)'),
#  (0.016150173426377694, 'SM(24:1)'),
#  (0.015174631135772441, 'SDMA'),
#  (0.014202277114081074, 'CER(24:1)'),
#  (0.013868045368177926, 'Tyr'),
#  (0.01379598539791341, 'Met-SO'),
#  (0.013782026595248662, 'Serotonin'),
#  (0.013399194815420547, 'SM(22:1)'),
#  (0.012779657580058968, 'SM(20:1)'),
#  (0.01260067518942452, 't4-OH-Pro'),
#  (0.012397628298055503, 'Asp'),
#  (0.012209727249151375, 'CER(18:0)'),
#  (0.011826590119173239, 'SM(26:1)'),
#  (0.01142923959923889, 'T_HCER'),
#  (0.011289192402493837, 'FPG'),
#  (0.01121105563186797, 'Taurine'),
#  (0.010212289687362036, 'DCER(22:1)'),
#  (0.009611236133997978, 'Trp'),
#  (0.009596805720254032, 'Met'),
#  (0.00955308760640837, 'T_CER'),
#  (0.009465322965374117, 'DCER(24:0)'),
#  (0.00944217317474893, 'Glu'),
#  (0.009268294089791714, 'SM C18:1'),
#  (0.009223008947221625, 'Pro'),
#  (0.009023849829364536, 'SM(20:0)'),
#  (0.008602242217578238, 'T_LPE'),
#  (0.00813102939104588, 'LCER(22:0)'),
#  (0.008129948442996601, 'Arg'),
#  (0.007965311346108658, 'LPC(14:0)'),
#  (0.007659611100400574, 'T_TAG'),
#  (0.00749399396411634, 'SM(14:0)'),
#  (0.007363698955365622, 'T_DCER'),
#  (0.007276778722366956, 'T_DAG'),
#  (0.007201083008526015, 'LCER(18:1)'),
#  (0.007104447726435881, 'SM (OH) C14:1'),
#  (0.006914280346565983, 'alpha-AAA'),
#  (0.006901846836924908, 'Asn'),
#  (0.006572600088922608, 'ADMA'),
#  (0.006550602330177927, 'CER(22:1)'),
#  (0.00644629478198345, 'CER(26:0)'),
#  (0.006376470588235294, 'HOMA_IR'),
#  (0.005560640732265446, 'CER(16:0)'),
#  (0.0055, 'SM(18:0)'),
#  (0.005460280927848571, 'Creatinine'),
#  (0.005453885263439522, 'Orn'),
#  (0.005262285419529166, 'total DMA'),
#  (0.0052422979797979805, 'SM (OH) C22:1'),
#  (0.005191662141505239, 'His'),
#  (0.0051701574909139856, 'Ser'),
#  (0.005119122257053291, 'SM(26:0)'),
#  (0.004882627665050433, 'SM(22:0)'),
#  (0.004880563629991547, 'CER(20:0)'),
#  (0.004599182128293637, 'HCER(24:0)'),
#  (0.004472449710421056, 'T_FFA'),
#  (0.004172882910245809, 'LCER(16:0)'),
#  (0.003909410253322094, 'Ile'),
#  (0.003714790929893904, 'SM(16:0)'),
#  (0.0034795574795574795, 'Gly'),
#  (0.0034616509851803975, 'Thr'),
#  (0.003419363044363044, 'T_LCER'),
#  (0.0031723597883597876, 'DCER(22:0)'),
#  (0.0030474856314905057, 'Phe'),
#  (0.0029979075856319025, 'Leu'),
#  (0.002883295194508009, 'T_PI'),
#  (0.002778008021390374, 'SM(18:1)'),
#  (0.0027542191604691614, 'HCER(22:0)'),
#  (0.0027162756598240454, 'T_PE'),
#  (0.0027083651302401302, 'T_LPC'),
#  (0.002533833573833575, 'LCER(18:0)'),
#  (0.0023920854880413703, 'SM (OH) C24:1'),
#  (0.002375870972478861, 'Ala'),
#  (0.0023574380165289257, 'Lys'),
#  (0.0023572037510656433, 'CER(14:0)'),
#  (0.0018288888888888888, 'SM(24:0)'),
#  (0.0017692947784480966, 'HCER(22:1)'),
#  (0.0017600822482839286, 'T_SM'),
#  (0.001388888888888889, 'Putrescine'),
#  (0.001375124512047382, 'SM C26:1'),
#  (0.0011454545454545454, 'SM C26:0'),
#  (0.0007208237986270023, 'T_PC'),
#  (0.0006481481481481482, 'SM C24:0'),
#  (0.0005185185185185185, 'Val'),
#  (0.0, 'Total_TAG'),
#  (0.0, 'T_CE'),
#  (0.0, 'Hexose'),
#  (0.0, 'DCER(24:1)')]

# %%
feat_importances = pd.Series(randomforest.feature_importances_, index = X.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.title("Top 10 important features")
plt.show()
